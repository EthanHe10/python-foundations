# %% [markdown]
# # Arithmetic Operators

# %% [markdown]
# ## 1. Addition

# %%
3 + 5
# Out:
# 8

# %%
222 + 1.45
# Out:
# 223.45

# %% [markdown]
# ## 2. Subtraction

# %%
123.45 - 23
# Out:
# 100.45

# %% [markdown]
# ## 3. Multiplication

# %%
34.56 * 222
# Out:
# 7672.320000000001

# %% [markdown]
# ## 4. Division

# %% [markdown]
# ### 4.1 floor division

# %%
11 // 3
# Out:
# 3

# %%
25 // 4
# Out:
# 6

# %%
11 // 3.0
# Out:
# 3.0

# %% [markdown]
# ### 4.2 real division

# %%
11 / 3
# Out:
# 3.6666666666666665

# %%
12 / 4
# Out:
# 3.0

# %% [markdown]
# ### 4.3 module operator

# %%
11 % 3
# Out:
# 2

# %%
11.2 % 3
# Out:
# 2.1999999999999993

# %%
11.0 % 3.0
# Out:
# 2.0

# %% [markdown]
# # 5. Power

# %%
2 ** 10
# Out:
# 1024

# %%
3 ** 1/2
# Out:
# 1.5

# %%
3 ** 0.5
# Out:
# 1.7320508075688772
