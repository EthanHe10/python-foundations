# %% [markdown]
# # Variables

# %% [markdown]
# A variable is a named storage location that associates a name with an object.
#
# Variables don't store data themselves, but instea store references to the objects that contain the data.
#
# A reference is the memory address of the location where teh object is stored.

# %% [markdown]
# # 1. Variable Assignment

# %%
name = "John"

id_number = 12345

height = 175

# %% [markdown]
# # 2. Alias

# %% [markdown]
# Both variables refer to the same object.

# %%
name = "John"

student = name

# %% [markdown]
# # 3. Null Reference

# %% [markdown]
# A variable is not set to reference any object.
#
# In python, there is a special object None for a null reference.

# %%
id_number = None

# %%
id_number

# %% [markdown]
# # 4. Constants

# %% [markdown]
# Python does not spport constant variables
#
# It's a common practice that we specify constant variables with all CAPITAL letters.

# %%
TAX_RATE = 0.15

MAX_SIZE = 1000
