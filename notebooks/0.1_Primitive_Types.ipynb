# %%
print("hello world!")
# Out:
# hello world!

# %%
50
# Out:
# 50

# %%
a=34
a
# Out:
# 34

# %%
25.45
# Out:
# 25.45

# %%
"abc"
# Out:
# 'abc'

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
[1, 2, 3, 4]
# Out:
# [1, 2, 3, 4]

# %%
[1, 2, True, "abc"]
# Out:
# [1, 2, True, 'abc']

# %%
[1, 2, True, "bbb"]
# Out:
# [1, 2, True, 'bbb']

# %%
dic1={123:"abc", 234:"ccc", 789:3.4}

# %%
dic1[123]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 dic1[123]
#
# NameError: name 'dic1' is not defined
